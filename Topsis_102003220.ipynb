# %% [markdown]
# <a href="https://colab.research.google.com/github/gurtaransingh/Machine-Learning-Assignments/blob/main/Topsis_102003220.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
#file upload
mydata=pd.read_csv('/content/Topsis-Dataset.csv')
mydata
# Out:
#   Model  Corr  Rseq  RMSE  Accuracy
# 0    M1  0.79  0.62  1.25     60.89
# 1    M2  0.66  0.44  2.89     63.07
# 2    M3  0.56  0.31  1.57     62.87
# 3    M4  0.82  0.67  2.68     70.19
# 4    M5  0.75  0.56  1.30     80.39

# %%
#weight
w = [2,3,1,0.5]

# %%
#impact
i = [-1, -1, 1, 1]

# %%
#element multipy
r = []
for j in range(0, len(w)):
    r.append(w[j] * i[j])

# %%
# r

# %%
first_column = mydata.columns[0]
# Delete first column
d = mydata.drop([first_column], axis=1)
d.to_csv('file.csv', index=False)
d = pd.DataFrame(d)
d
# Out:
#    Corr  Rseq  RMSE  Accuracy
# 0  0.79  0.62  1.25     60.89
# 1  0.66  0.44  2.89     63.07
# 2  0.56  0.31  1.57     62.87
# 3  0.82  0.67  2.68     70.19
# 4  0.75  0.56  1.30     80.39

# %%
d1 = d

# %%
def func(df, col):
  df[col] = df[col] / np.sqrt(df[col].sum())

# %%
d=d*d
d
# Out:
#      Corr    Rseq    RMSE   Accuracy
# 0  0.6241  0.3844  1.5625  3707.5921
# 1  0.4356  0.1936  8.3521  3977.8249
# 2  0.3136  0.0961  2.4649  3952.6369
# 3  0.6724  0.4489  7.1824  4926.6361
# 4  0.5625  0.3136  1.6900  6462.5521

# %%
# for i in range(len(d)-1):
for i in range(d.shape[1]):
  func(d, d.columns[i])

# %%
d
# Out:
#        Corr      Rseq      RMSE   Accuracy
# 0  0.386441  0.320712  0.338939  24.432673
# 1  0.269723  0.161524  1.811744  26.213481
# 2  0.194180  0.080178  0.534688  26.047495
# 3  0.416349  0.374526  1.558012  32.466055
# 4  0.348299  0.261642  0.366596  42.587593

# %%
d=d*r
# d
# Out:
#        Corr      Rseq      RMSE   Accuracy
# 0 -0.772883 -0.962137  0.338939  12.216337
# 1 -0.539445 -0.484572  1.811744  13.106741
# 2 -0.388361 -0.240534  0.534688  13.023747
# 3 -0.832697 -1.123577  1.558012  16.233028
# 4 -0.696598 -0.784927  0.366596  21.293796

# %%
d.sum(axis=1)

# for i in range(len(d)):
#   d["Topsis Score 2"] = d.sum(axis=1)
# d

d["Topsis Score"] = d.sum(axis=1)
# d

# %%
ranks = list(range(len(d)))
Rank = [x for x in ranks]
d['Index']=Rank
# d

# %%
d = d.sort_values(by=['Topsis Score'], ascending=False)
# d

# %%
ranks = list(range(len(d)))
Rank = [x+1 for x in ranks]
d['Rank']=Rank
# d

# %%
d = d.sort_values(by=['Index'])
# d

# %%
# d1

# %%
d1['Topsis Score'] = d['Topsis Score']
d1['Rank'] = d['Rank']
d1
# Out:
#    Corr  Rseq  RMSE  Accuracy  Topsis Score  Rank
# 0  0.79  0.62  1.25     60.89     10.820256     5
# 1  0.66  0.44  2.89     63.07     13.894467     3
# 2  0.56  0.31  1.57     62.87     12.929540     4
# 3  0.82  0.67  2.68     70.19     15.834764     2
# 4  0.75  0.56  1.30     80.39     20.178868     1
